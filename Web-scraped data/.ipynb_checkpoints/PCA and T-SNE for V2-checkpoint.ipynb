# 16  0.320517  0.107253                     1   Non-governmental organizations
# 17  0.789510  0.000151                     3  Intergovernmental organizations
# 18  0.991207  0.000101                     3   Non-governmental organizations
# 19  0.876011  0.036540                     3  Intergovernmental organizations
#
#                          coordinator           city                   country  \
# 0               Mr. Thibaut Ghirardi          Paris                    France
# 1                      Mr. Flip Vonk      Amsterdam               Netherlands
# 2                    Ms. Lucie Greyl           Rome                     Italy
# 3                 Mr. Thorsten Göbel         Geneva               Switzerland
# 4          Mr. Kenneth Nana Amoateng           Tena                     Ghana
# 5            Mr. Sreedhar Ramamurthi      New Delhi                     India
# 6    Mr. Mahamadoun Abdoulaye Traore  Aubervilliers                    France
# 7                  M. Dietmar Mirkes     Luxembourg                Luxembourg
# 8   Ms. Teresa Maria Isabel Anderson   Johannesburg              South Africa
# 9         Mr. Mikko Antti Ollikainen  Washington DC  United States of America
# 10               Mr. Dennis Taenzler         Berlin                   Germany
# 11                 Mr. Dean Wallraff   Shadow Hills  United States of America
# 12       Mr. Peter Olugbenga Adeleye         Kurudu                   Nigeria
# 13             Mr. Tunji John Asaolu          Abuja                   Nigeria
# 14            Mr. Kennedy Liti Mbeva        Nairobi                     Kenya
# 15                    Ms. Safia Alfa         Niamey                     Niger
# 16                     Mr. Nura Jibo          Dutse                   Nigeria
# 17            Ms. Louise Helen Brown          Tunis                   Tunisia
# 18                 Mr. Godwin Kowero        Nairobi                     Kenya
# 19          Mr. Harsen Nyambe Nyambe    Addis Ababa                  Ethiopia
#
#    iso3      continent         income_group
# 0   FRA         Europe          High income
# 1   NLD         Europe          High income
# 2   ITA         Europe          High income
# 3   CHE         Europe          High income
# 4   GHA         Africa  Lower middle income
# 5   IND           Asia  Lower middle income
# 6   FRA         Europe          High income
# 7   LUX         Europe          High income
# 8   ZAF         Africa  Upper middle income
# 9   USA  North America          High income
# 10  DEU         Europe          High income
# 11  USA  North America          High income
# 12  NGA         Africa  Lower middle income
# 13  NGA         Africa  Lower middle income
# 14  KEN         Africa  Lower middle income
# 15  NER         Africa           Low income
# 16  NGA         Africa  Lower middle income
# 17  TUN         Africa  Lower middle income
# 18  KEN         Africa  Lower middle income
# 19  ETH         Africa           Low income

# %%
df.describe()
# Out:
#             Topic1       Topic2       Topic3       Topic4  \
# count  1118.000000  1118.000000  1118.000000  1118.000000
# mean      0.369532     0.073450     0.319255     0.237764
# std       0.324024     0.138696     0.306405     0.306850
# min       0.000066     0.000008     0.000038     0.000034
# 25%       0.055936     0.000024     0.030305     0.016070
# 50%       0.286770     0.000070     0.233740     0.091860
# 75%       0.661606     0.067384     0.550809     0.323881
# max       0.999848     0.860086     0.999729     0.999853
#
#        most_prevalent_topic
# count           1118.000000
# mean               2.367621
# std                1.210188
# min                1.000000
# 25%                1.000000
# 50%                3.000000
# 75%                3.000000
# max                4.000000

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
x = df[['Topic1', 'Topic2', 'Topic3', 'Topic4']]
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['PC1', 'PC2'])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.918706508600031

# %%
final = pd.concat([df,principalDf], axis=1)

# %%
final
# Out:
#                                            organization  \
# 0                        2° investing initiative (2°ii)
# 1                                         A SEED Europe
# 2                 A Sud Ecology and Cooperation - Onlus
# 3            ACT Alliance - Action by Churches Together
# 4                                  Abibimman Foundation
# ...                                                 ...
# 1113                            ZOI Environment Network
# 1114  Zhenjiang Green Sanshan Environmental Public W...
# 1115                                    atmosfair gGmbH
# 1116                                      iuventum e.V.
# 1117                                      urgewald e.V.
#
#                                            merged_texts    Topic1    Topic2  \
# 0     2 Degrees Investing Initiative - World Benchma...  0.901824  0.000062
# 1     Magic Garden Seeds - Samen & Saatgut Coupon Re...  0.245678  0.359987
# 2     Who we are - Progetto Sud | Istituto per la Co...  0.248977  0.196837
# 3     About us | ACT Alliance EU About us – ACT Alli...  0.010819  0.011843
# 4     Abibiman Foundation Home Who we are Board of D...  0.687646  0.000035
# ...                                                 ...       ...       ...
# 1113  Products | Zoï Environment Network Home About...  0.861107  0.033107
# 1114  Department of Human Services [if IE 9] You may...  0.132431  0.000037
# 1115  Emissions calculation - atmosfair Contact FAQs...  0.999826  0.000020
# 1116  iuventum - Wikipedia iuventum From Wikipedia, ...  0.006273  0.000022
# 1117  Our team | urgewald e.V. Skip to content. Home...  0.999848  0.000018
#
#         Topic3    Topic4  most_prevalent_topic  \
# 0     0.095155  0.002959                     1
# 1     0.224041  0.170293                     2
# 2     0.498621  0.055564                     3
# 3     0.931358  0.045980                     3
# 4     0.287628  0.024691                     1
# ...        ...       ...                   ...
# 1113  0.105561  0.000225                     1
# 1114  0.270195  0.597338                     4
# 1115  0.000079  0.000075                     1
# 1116  0.978501  0.015204                     3
# 1117  0.000069  0.000065                     1
#
#                          entity_type                coordinator        city  \
# 0     Non-governmental organizations       Mr. Thibaut Ghirardi       Paris
# 1     Non-governmental organizations              Mr. Flip Vonk   Amsterdam
# 2     Non-governmental organizations            Ms. Lucie Greyl        Rome
# 3     Non-governmental organizations         Mr. Thorsten Göbel      Geneva
# 4     Non-governmental organizations  Mr. Kenneth Nana Amoateng        Tena
# ...                              ...                        ...         ...
# 1113  Non-governmental organizations         Mr. Viktor Novikov      Geneva
# 1114  Non-governmental organizations                        NaN    中国江苏省镇江市
# 1115  Non-governmental organizations       Ms. Cathleen Herrich      Berlin
# 1116  Non-governmental organizations         Mr. Henning Stöcks      Velzen
# 1117  Non-governmental organizations           Ms. Kathrin Petz  Sassenberg
#
#           country iso3 continent         income_group       PC1       PC2
# 0          France  FRA    Europe          High income  0.617839 -0.092019
# 1     Netherlands  NLD    Europe          High income -0.044863  0.016395
# 2           Italy  ITA    Europe          High income -0.137272 -0.242955
# 3     Switzerland  CHE    Europe          High income -0.535327 -0.496430
# 4           Ghana  GHA    Africa  Lower middle income  0.341567 -0.175043
# ...           ...  ...       ...                  ...       ...       ...
# 1113  Switzerland  CHE    Europe          High income  0.579032 -0.097062
# 1114        China  CHN      Asia  Upper middle income -0.273732  0.332640
# 1115      Germany  DEU    Europe          High income  0.745610 -0.044179
# 1116      Germany  DEU    Europe          High income -0.552677 -0.549205
# 1117      Germany  DEU    Europe          High income  0.745635 -0.044182
#
# [1118 rows x 16 columns]

# %%
final.to_csv("V2_PCA_RAW_DATA.csv")

# %%
final = pd.read_csv("V2_PCA_RAW_DATA.csv", index_col=0)

# %%
# Out:
# Empty DataFrame
# Columns: [organization, merged_texts, Topic1, Topic2, Topic3, Topic4, most_prevalent_topic, entity_type, coordinator, city, country, iso3, continent, income_group, PC1, PC2]
# Index: []

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
ax = sns.relplot(x = 'PC1',
              y = 'PC2',
              data = final,
              hue = 'most_prevalent_topic',
                palette = sns.color_palette("tab10")[0:4],
               style = 'income_group',
                style_order=['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
               height = 10,
               aspect = 1.1
              )
ax.set(title = "PCA Decomposition of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, n = 1118)")
ax._legend.texts[0].set_text("Most Prevalent Topic")
ax._legend.texts[5].set_text("Income Group")

plt.savefig("V2_pca_vis1", dpi = 500, facecolor = 'white', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
ax = sns.relplot(x = 'PC1',
              y = 'PC2',
              data = final,
              hue = 'most_prevalent_topic',
                palette = sns.color_palette("tab10")[0:4],
               style = 'continent',
                 style_order=['North America', 'Europe', 'Asia', 'South America', 'Africa', 'Oceania'],
               height = 10,
               aspect = 1.1
              )
ax.set(title = "PCA Decomposition of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, n = 1118)")
ax._legend.texts[0].set_text("Most Prevalent Topic")
ax._legend.texts[5].set_text("Continent")
plt.savefig("V2_pca_vis2", dpi = 500, facecolor = 'white', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
ax = sns.relplot(x = 'PC1',
              y = 'PC2',
              data = final,
                 col = 'most_prevalent_topic',
                 col_wrap = 2,
               hue = 'income_group',
                 palette=sns.color_palette("rocket")[0:4],
                 style = 'income_group',
                 style_order = ['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
                hue_order=['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
               height = 10,
               aspect = 0.7
              )


ax.set_titles(col_template="Most Prevalent Topic = {col_name}")
ax.fig.suptitle("PCA Decomposition of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, n = 1118)",
               y=1.01)
ax._legend.set_title("Income Group")
plt.savefig("V2_pca_vis3", dpi = 500, facecolor = 'white', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


ax = sns.relplot(x = 'PC1',
              y = 'PC2',
              data = final,
                 col = 'most_prevalent_topic',
                 col_wrap = 2,
               style = 'continent',
                 hue = 'continent',
                 hue_order = ['North America', 'Europe', 'Asia', 'South America', 'Africa', 'Oceania'],
                 style_order=['North America', 'Europe', 'Asia', 'South America', 'Africa', 'Oceania'],
               height = 10,
               aspect = 0.7
              )


ax.set_titles(col_template="Most Prevalent Topic = {col_name}")
ax.fig.suptitle("PCA Decomposition of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, n = 1118)",
               y=1.01)
ax._legend.set_title("Continent")

plt.savefig("V2_pca_vis4", dpi = 500, facecolor = 'white', bbox_inches = 'tight')

# %% [markdown]
# ## T-SNE

# %%
from sklearn.manifold import TSNE
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca', perplexity=30)
tsne_lda = tsne_model.fit_transform(x)

tsne_data = pd.DataFrame(data = tsne_lda,
                           columns = ['X', 'Y'])
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1118 samples in 0.001s...
# [t-SNE] Computed neighbors for 1118 samples in 0.024s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1118
# [t-SNE] Computed conditional probabilities for sample 1118 / 1118
# [t-SNE] Mean sigma: 0.043907
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.697464
# [t-SNE] KL divergence after 1000 iterations: 0.471631

# %%
final_tsne = pd.concat([df,tsne_data], axis=1)

# %%
final_tsne
# Out:
#                                            organization  \
# 0                        2° investing initiative (2°ii)
# 1                                         A SEED Europe
# 2                 A Sud Ecology and Cooperation - Onlus
# 3            ACT Alliance - Action by Churches Together
# 4                                  Abibimman Foundation
# ...                                                 ...
# 1113                            ZOI Environment Network
# 1114  Zhenjiang Green Sanshan Environmental Public W...
# 1115                                    atmosfair gGmbH
# 1116                                      iuventum e.V.
# 1117                                      urgewald e.V.
#
#                                            merged_texts    Topic1    Topic2  \
# 0     2 Degrees Investing Initiative - World Benchma...  0.901824  0.000062
# 1     Magic Garden Seeds - Samen & Saatgut Coupon Re...  0.245678  0.359987
# 2     Who we are - Progetto Sud | Istituto per la Co...  0.248977  0.196837
# 3     About us | ACT Alliance EU About us – ACT Alli...  0.010819  0.011843
# 4     Abibiman Foundation Home Who we are Board of D...  0.687646  0.000035
# ...                                                 ...       ...       ...
# 1113  Products | Zoï Environment Network Home About...  0.861107  0.033107
# 1114  Department of Human Services [if IE 9] You may...  0.132431  0.000037
# 1115  Emissions calculation - atmosfair Contact FAQs...  0.999826  0.000020
# 1116  iuventum - Wikipedia iuventum From Wikipedia, ...  0.006273  0.000022
# 1117  Our team | urgewald e.V. Skip to content. Home...  0.999848  0.000018
#
#         Topic3    Topic4  most_prevalent_topic  \
# 0     0.095155  0.002959                     1
# 1     0.224041  0.170293                     2
# 2     0.498621  0.055564                     3
# 3     0.931358  0.045980                     3
# 4     0.287628  0.024691                     1
# ...        ...       ...                   ...
# 1113  0.105561  0.000225                     1
# 1114  0.270195  0.597338                     4
# 1115  0.000079  0.000075                     1
# 1116  0.978501  0.015204                     3
# 1117  0.000069  0.000065                     1
#
#                          entity_type                coordinator        city  \
# 0     Non-governmental organizations       Mr. Thibaut Ghirardi       Paris
# 1     Non-governmental organizations              Mr. Flip Vonk   Amsterdam
# 2     Non-governmental organizations            Ms. Lucie Greyl        Rome
# 3     Non-governmental organizations         Mr. Thorsten Göbel      Geneva
# 4     Non-governmental organizations  Mr. Kenneth Nana Amoateng        Tena
# ...                              ...                        ...         ...
# 1113  Non-governmental organizations         Mr. Viktor Novikov      Geneva
# 1114  Non-governmental organizations                        NaN    中国江苏省镇江市
# 1115  Non-governmental organizations       Ms. Cathleen Herrich      Berlin
# 1116  Non-governmental organizations         Mr. Henning Stöcks      Velzen
# 1117  Non-governmental organizations           Ms. Kathrin Petz  Sassenberg
#
#           country iso3 continent         income_group   tsne_pc1   tsne_pc2
# 0          France  FRA    Europe          High income  29.017643   0.482165
# 1     Netherlands  NLD    Europe          High income   4.277696  -5.982986
# 2           Italy  ITA    Europe          High income  -0.790087 -13.286133
# 3     Switzerland  CHE    Europe          High income -29.123688 -11.644621
# 4           Ghana  GHA    Africa  Lower middle income  17.216631 -16.938927
# ...           ...  ...       ...                  ...        ...        ...
# 1113  Switzerland  CHE    Europe          High income  26.934475   0.178325
# 1114        China  CHN      Asia  Upper middle income -14.376551  12.906436
# 1115      Germany  DEU    Europe          High income  38.197216   4.100366
# 1116      Germany  DEU    Europe          High income -32.463310 -11.586370
# 1117      Germany  DEU    Europe          High income  38.187195   3.680417
#
# [1118 rows x 16 columns]

# %%
F.to_csv("V2_TSNE_RAW_DATA_perp30.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
ax = sns.relplot(x = 'X',
              y = 'Y',
              data = final_tsne,
              hue = 'most_prevalent_topic',
                palette = sns.color_palette("tab10")[0:4],
               style = 'income_group',
                style_order=['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
               height = 10,
               aspect = 1.5
              )
ax.set(title = "T-SNE Plot of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, perplexity = 30, n = 1118)",
      xlabel = "T-SNE PC1",
      ylabel = "T-SNE PC2")
ax._legend.texts[0].set_text("Most Prevalent Topic")
ax._legend.texts[5].set_text("Income Group")
plt.savefig("V2_tsne_perplex30_vis1", dpi = 500, facecolor = 'white', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
ax = sns.relplot(x = 'X',
              y = 'Y',
              data = final_tsne,
              hue = 'most_prevalent_topic',
                palette = sns.color_palette("tab10")[0:4],
               style = 'continent',
                 style_order=['North America', 'Europe', 'Asia', 'South America', 'Africa', 'Oceania'],
               height = 10,
               aspect = 1.5
              )
ax.set(title = "T-SNE Plot of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, perplexity = 30, n = 1118)",
      xlabel = "T-SNE PC1",
      ylabel = "T-SNE PC2")
ax._legend.texts[0].set_text("Most Prevalent Topic")
ax._legend.texts[5].set_text("Income Group")
plt.savefig("V2_tsne_perplex30_vis2", dpi = 500, facecolor = 'white', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.relplot(x = 'X',
              y = 'Y',
              data = final_tsne,
                 col = 'most_prevalent_topic',
                 col_wrap = 2,
                 hue = 'income_group',
                 palette = sns.color_palette("rocket")[0:4],
                 hue_order=['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
               height = 10,
               aspect = 0.7
              )



ax.set_titles(col_template="Most Prevalent Topic = {col_name}")
ax.set(xlabel = "T-SNE PC1",
      ylabel = "T-SNE PC2")
ax.fig.suptitle("T-SNE of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, perplexity = 30, n = 1118)",
               y=1.02)
ax._legend.set_title("Income Group")
# plt.savefig("V2_tsne_perplex30_vis3", dpi = 400, facecolor = 'white', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.relplot(x = 'X',
              y = 'Y',
              data = final_tsne,
                 col = 'most_prevalent_topic',
                 col_wrap = 2,
                 style = 'continent',
                 hue = 'continent',
                 hue_order = ['North America', 'Europe', 'Asia', 'South America', 'Africa', 'Oceania'],
                 style_order=['North America', 'Europe', 'Asia', 'South America', 'Africa', 'Oceania'],
               height = 10,
               aspect = 0.7
              )



ax.set_titles(col_template="Most Prevalent Topic = {col_name}")
ax.set(xlabel = "T-SNE PC1",
      ylabel = "T-SNE PC2")
ax.fig.suptitle("T-SNE of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, perplexity = 30, n = 1118)",
               y=1.02)
ax._legend.set_title("Continent")
plt.savefig("V2_tsne_perplex30_vis4", dpi = 400, facecolor = 'white', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.relplot(x = 'X',
              y = 'Y',
              data = final_tsne,
                 col = 'most_prevalent_topic',
                 col_wrap = 2,
                 hue = 'income_group',
                 palette = ['#2ca02c', '#1f77b4', '#ff7f0e', '#d62728'],
                 hue_order=['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
                 style = 'income_group',
                 style_order=['High income', 'Upper middle income', 'Lower middle income', 'Low income'],
               height = 10,
               aspect = 0.7
              )



ax.set_titles(col_template="Most Prevalent Topic = {col_name}")
ax.set(xlabel = "T-SNE PC1",
      ylabel = "T-SNE PC2")
ax.fig.suptitle("T-SNE of Topic Proportions for All NGOs and IGOs \n (COP 2019, 4-topic LDA model, perplexity = 30, n = 1118)",
               y=1.02)
ax._legend.set_title("Income Group")
plt.savefig("V2_tsne_perplex30_vis5", dpi = 400, facecolor = 'white', bbox_inches = 'tight')
