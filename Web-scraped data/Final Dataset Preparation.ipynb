# %%
import numpy as np
import pandas as pd

# %%
foreign = pd.read_csv("FOREIGN_TRUNCATED_12558CHR_translated.csv", index_col=0)

# %%
foreign
# Out:
#                                                   Text  \
# X
# 0    Historique de la création – Autorité de Dév...
# 1    Autorité de Développement Intégré des Etat...
# 2    Etats membres – Autorité de Développement In...
# 3    Emplois – Autorité de Développement Intégre...
# 4    ALG - Autorité de Développement Intégré de...
# ..                                                 ...
# 551  Toggle navigation 99jobs Acesse sua contaou ca...
# 552  Saltar para o conteúdo Alternar barra lateral...
# 553  no image Instituto Global Attitude STI e OECD:...
# 554  OPPORTUNITIESPROJECTSGRANTMAKERSENTREPRENEURSl...
# 555  BRASILCORONAVÍRUS (COVID-19) Simplifique!Part...
#
#                                           organization original_language  \
# X
# 0    Autorité de développement intégré de la région...            french
# 1    Autorité de développement intégré de la région...            french
# 2    Autorité de développement intégré de la région...            french
# ...

# %%
foreign.reset_index(drop=True, inplace=True)

# %%
foreign
# Out:
#                                                   Text  \
# 0    Historique de la création – Autorité de Dév...
# 1    Autorité de Développement Intégré des Etat...
# 2    Etats membres – Autorité de Développement In...
# 3    Emplois – Autorité de Développement Intégre...
# 4    ALG - Autorité de Développement Intégré de...
# ..                                                 ...
# 551  Toggle navigation 99jobs Acesse sua contaou ca...
# 552  Saltar para o conteúdo Alternar barra lateral...
# 553  no image Instituto Global Attitude STI e OECD:...
# 554  OPPORTUNITIESPROJECTSGRANTMAKERSENTREPRENEURSl...
# 555  BRASILCORONAVÍRUS (COVID-19) Simplifique!Part...
#
#                                           organization original_language  \
# 0    Autorité de développement intégré de la région...            french
# 1    Autorité de développement intégré de la région...            french
# 2    Autorité de développement intégré de la région...            french
# ...

# %%
foreign = foreign[["Text", "organization", "original_language", "Text_translated"]]

# %%
foreign
# Out:
#                                                   Text  \
# 0    Historique de la création – Autorité de Dév...
# 1    Autorité de Développement Intégré des Etat...
# 2    Etats membres – Autorité de Développement In...
# 3    Emplois – Autorité de Développement Intégre...
# 4    ALG - Autorité de Développement Intégré de...
# ..                                                 ...
# 551  Toggle navigation 99jobs Acesse sua contaou ca...
# 552  Saltar para o conteúdo Alternar barra lateral...
# 553  no image Instituto Global Attitude STI e OECD:...
# 554  OPPORTUNITIESPROJECTSGRANTMAKERSENTREPRENEURSl...
# 555  BRASILCORONAVÍRUS (COVID-19) Simplifique!Part...
#
#                                           organization original_language  \
# 0    Autorité de développement intégré de la région...            french
# 1    Autorité de développement intégré de la région...            french
# 2    Autorité de développement intégré de la région...            french
# ...

# %%
original = pd.read_csv("cleaned_texts_round1_with_language.csv", index_col=0)

# %%
original
# Out:
#                                                    Text  \
# 0     10 Years of the Adaptation Fund - Pioneering A...
# 1     About 10 Years of the Adaptation Fund Stories ...
# 2     Contact 10 Years of the Adaptation Fund Storie...
# 3     Governance - Adaptation Fund 10 Years of the A...
# 4     AF | Adaptation Fund 10 Years of the Adaptatio...
# ...                                                 ...
# 5864  Lensa Blog Sign up Log in Seatrust Institute S...
# 5865  Skip to main content Microsites menu UNFCCC Si...
# 5866  Skip to Content Menu Alumni Contact Us Help Ce...
# 5867  Owler - Community driven business intelligence...
# 5868  Skip to main contentwe ADAPT | Climate change ...
#
#                organization original_language
# 0     Adaptation Fund Board           ENGLISH
# 1     Adaptation Fund Board           ENGLISH
# 2     Adaptation Fund Board           ENGLISH
# 3     Adaptation Fund Board           ENGLISH
# 4     Adaptation Fund Board           ENGLISH
# ...

# %%
original = original[original.original_language == 'ENGLISH']

# %%
original.reset_index(drop=True, inplace=True)

# %%
original
# Out:
#                                                    Text  \
# 0     10 Years of the Adaptation Fund - Pioneering A...
# 1     About 10 Years of the Adaptation Fund Stories ...
# 2     Contact 10 Years of the Adaptation Fund Storie...
# 3     Governance - Adaptation Fund 10 Years of the A...
# 4     AF | Adaptation Fund 10 Years of the Adaptatio...
# ...                                                 ...
# 5308  Lensa Blog Sign up Log in Seatrust Institute S...
# 5309  Skip to main content Microsites menu UNFCCC Si...
# 5310  Skip to Content Menu Alumni Contact Us Help Ce...
# 5311  Owler - Community driven business intelligence...
# 5312  Skip to main contentwe ADAPT | Climate change ...
#
#                organization original_language
# 0     Adaptation Fund Board           ENGLISH
# 1     Adaptation Fund Board           ENGLISH
# 2     Adaptation Fund Board           ENGLISH
# 3     Adaptation Fund Board           ENGLISH
# 4     Adaptation Fund Board           ENGLISH
# ...

# %%
L = len(original.original_language)
original.original_language = (['english']*L)
# Out:
# /Users/stefan/py_38_env/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
original
# Out:
#                                                    Text  \
# 0     10 Years of the Adaptation Fund - Pioneering A...
# 1     About 10 Years of the Adaptation Fund Stories ...
# 2     Contact 10 Years of the Adaptation Fund Storie...
# 3     Governance - Adaptation Fund 10 Years of the A...
# 4     AF | Adaptation Fund 10 Years of the Adaptatio...
# ...                                                 ...
# 5308  Lensa Blog Sign up Log in Seatrust Institute S...
# 5309  Skip to main content Microsites menu UNFCCC Si...
# 5310  Skip to Content Menu Alumni Contact Us Help Ce...
# 5311  Owler - Community driven business intelligence...
# 5312  Skip to main contentwe ADAPT | Climate change ...
#
#                organization original_language
# 0     Adaptation Fund Board           english
# 1     Adaptation Fund Board           english
# 2     Adaptation Fund Board           english
# 3     Adaptation Fund Board           english
# 4     Adaptation Fund Board           english
# ...

# %%
# see the limit of truncation
M = max([len(x) for x in foreign.Text])
M
# Out:
# 12558

# %%
# the limit of truncation is thus 12558
truncated_texts = [x[0:12558] for x in original.Text]
original.Text = truncated_texts
# Out:
# /Users/stefan/py_38_env/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
original
# Out:
#                                                    Text  \
# 0     10 Years of the Adaptation Fund - Pioneering A...
# 1     About 10 Years of the Adaptation Fund Stories ...
# 2     Contact 10 Years of the Adaptation Fund Storie...
# 3     Governance - Adaptation Fund 10 Years of the A...
# 4     AF | Adaptation Fund 10 Years of the Adaptatio...
# ...                                                 ...
# 5308  Lensa Blog Sign up Log in Seatrust Institute S...
# 5309  Skip to main content Microsites menu UNFCCC Si...
# 5310  Skip to Content Menu Alumni Contact Us Help Ce...
# 5311  Owler - Community driven business intelligence...
# 5312  Skip to main contentwe ADAPT | Climate change ...
#
#                organization original_language
# 0     Adaptation Fund Board           english
# 1     Adaptation Fund Board           english
# 2     Adaptation Fund Board           english
# 3     Adaptation Fund Board           english
# 4     Adaptation Fund Board           english
# ...

# %%
m = max([len(x) for x in original.Text])
m
# Out:
# 12558

# %%
original["Text_translated"] = original.Text
# Out:
# /var/folders/6_/r43fszfx0sq37gltljwc7qqr0000gn/T/ipykernel_19365/229006558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   original["Text_translated"] = original.Text

# %%
original
# Out:
#                                                    Text  \
# 0     10 Years of the Adaptation Fund - Pioneering A...
# 1     About 10 Years of the Adaptation Fund Stories ...
# 2     Contact 10 Years of the Adaptation Fund Storie...
# 3     Governance - Adaptation Fund 10 Years of the A...
# 4     AF | Adaptation Fund 10 Years of the Adaptatio...
# ...                                                 ...
# 5308  Lensa Blog Sign up Log in Seatrust Institute S...
# 5309  Skip to main content Microsites menu UNFCCC Si...
# 5310  Skip to Content Menu Alumni Contact Us Help Ce...
# 5311  Owler - Community driven business intelligence...
# 5312  Skip to main contentwe ADAPT | Climate change ...
#
#                organization original_language  \
# 0     Adaptation Fund Board           english
# 1     Adaptation Fund Board           english
# 2     Adaptation Fund Board           english
# 3     Adaptation Fund Board           english
# 4     Adaptation Fund Board           english
# ...

# %%
FINAL_DF = pd.concat([foreign, original])

# %%
FINAL_DF
# Out:
#                                                    Text  \
# 0     Historique de la création – Autorité de Dév...
# 1     Autorité de Développement Intégré des Etat...
# 2     Etats membres – Autorité de Développement In...
# 3     Emplois – Autorité de Développement Intégre...
# 4     ALG - Autorité de Développement Intégré de...
# ...                                                 ...
# 5308  Lensa Blog Sign up Log in Seatrust Institute S...
# 5309  Skip to main content Microsites menu UNFCCC Si...
# 5310  Skip to Content Menu Alumni Contact Us Help Ce...
# 5311  Owler - Community driven business intelligence...
# 5312  Skip to main contentwe ADAPT | Climate change ...
#
#                                            organization original_language  \
# 0     Autorité de développement intégré de la région...            french
# 1     Autorité de développement intégré de la région...            french
# ...

# %%
FINAL_DF.sort_values(by = "organization", inplace = True)

# %%
FINAL_DF
# Out:
#                                                    Text  \
# 360   2 Degrees Investing Initiative - World Benchma...
# 361   2 Degrees Investing Initiative in standoff wit...
# 359   2° Investing Initiative GRESB About Our Work O...
# 362   Magic Garden Seeds - Samen & Saatgut Coupon Re...
# 363   A SEED Europe | European Youth Portal Den euro...
# ...                                                 ...
# 4877  Urgewald in English Direkt zum Inhalt Startsei...
# 4876  Prizes and awards | urgewald e.V. Direkt zum I...
# 4875  Articles & Quotes About Urgewald | urgewald e....
# 4874  Who we are | urgewald e.V. Direkt zum Inhalt S...
# 541   Startseite | urgewald e.V. Direkt zum Inhalt S...
#
#                         organization original_language  \
# 360   2° investing initiative (2°ii)           english
# 361   2° investing initiative (2°ii)           english
# 359   2° investing initiative (2°ii)           english
# 362                    A SEED Europe           english
# ...

# %%
FINAL_DF.reset_index(drop = True, inplace = True)

# %%
T = max([len(x) for x in FINAL_DF.Text])
