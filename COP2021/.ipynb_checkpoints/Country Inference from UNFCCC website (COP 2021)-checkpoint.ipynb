# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import seaborn as sns
import pycountry_convert as pycountry
import plotly.express as px
# %matplotlib inline

# %%
all_orgs = pd.read_csv("COP2021_orgnames.csv")

# %%
all_orgs.head()
# Out:
#                   name entity_type
# 0              Albania     Parties
# 1              Algeria     Parties
# 2              Andorra     Parties
# 3               Angola     Parties
# 4  Antigua and Barbuda     Parties

# %%
all_orgs.entity_type.unique()
# Out:
# array(['Parties', 'Observer States',
#        'United Nations Secretariat units and bodies',
#        'Specialized agencies and related organizations',
#        'Intergovernmental organizations',
#        'Non-governmental organizations'], dtype=object)

# %%
NGO = all_orgs[all_orgs.entity_type == 'Non-governmental organizations'].copy()
IGO = all_orgs[all_orgs.entity_type == 'Intergovernmental organizations'].copy()
NGO.reset_index(drop = True, inplace = True)
IGO.reset_index(drop = True, inplace = True)

# %%
NGO.head()
# Out:
#                                   name                     entity_type
# 0                   2050 Climate Group  Non-governmental organizations
# 1              2° investing initiative  Non-governmental organizations
# 2  350 the Climate Movement in Denmark  Non-governmental organizations
# 3                              350.org  Non-governmental organizations
# 4                A Rocha International  Non-governmental organizations

# %%
IGO.head()
# Out:
#                                                 name  \
# 0                              Adaptation Fund Board
# 1  African Centre of Meteorological Application f...
# 2                     African Development Bank Group
# 3                           African Union Commission
# 4           African, Caribbean and Pacific of States
#
#                        entity_type
# 0  Intergovernmental organizations
# 1  Intergovernmental organizations
# 2  Intergovernmental organizations
# 3  Intergovernmental organizations
# 4  Intergovernmental organizations

# %%
initial_NGO = len(NGO.name) * [np.nan]
initial_IGO = len(IGO.name) * [np.nan]
NGO["constituency"], NGO["coordinator"], NGO["city"], NGO["country"] = initial_NGO, initial_NGO, initial_NGO, initial_NGO
IGO["constituency"], IGO["coordinator"], IGO["city"], IGO["country"] = initial_IGO, initial_IGO, initial_IGO, initial_IGO

# %%
NGO.head()
# Out:
#                                   name                     entity_type  \
# 0                   2050 Climate Group  Non-governmental organizations
# 1              2° investing initiative  Non-governmental organizations
# 2  350 the Climate Movement in Denmark  Non-governmental organizations
# 3                              350.org  Non-governmental organizations
# 4                A Rocha International  Non-governmental organizations
#
#    constituency  coordinator  city  country
# 0           NaN          NaN   NaN      NaN
# 1           NaN          NaN   NaN      NaN
# 2           NaN          NaN   NaN      NaN
# 3           NaN          NaN   NaN      NaN
# 4           NaN          NaN   NaN      NaN

# %%
print(len(NGO.name), len(IGO.name))
# Out:
# 1597 75

# %%
NGO_unfccc = pd.read_csv("updated_NGOs_UNFCCC.csv")
NGO_unfccc
# Out:
#                                           Official Name           City  \
# 0     #13 Foundation Climate and Sustainable Develop...         Warsaw
# 1                                      10:10 Foundation         London
# 2                        2° investing initiative (2°ii)          Paris
# 3                                    2050 Climate Group      Edinburgh
# 4         350 the Climate Movement in Denmark (350 KiD)     Copenhagen
# ...                                                 ...            ...
# 2850  Zhenjiang Green Sanshan Environmental Public W...       中国江苏省镇江市
# 2851                      ZOI Environment Network (ZOI)         Geneva
# 2852            Zonta International CommitteeMs. Megan   Oak Brook, IL
# 2853                 Zoological Society of London (ZSL)         London
# 2854       Zurich University of Applied Sciences (ZHAW)     Winterthur
#
#                                                 Country  \
# 0                                                Poland
# 1     United Kingdom of Great Britain and Northern I...
# 2                                                France
# 3     United Kingdom of Great Britain and Northern I...
# 4                                               Denmark
# ...                                                 ...
# 2850                                              China
# 2851                                        Switzerland
# 2852                           United States of America
# 2853  United Kingdom of Great Britain and Northern I...
# 2854                                        Switzerland
#
#                                  Constituency              Phone  \
# 0                Constituency - Environmental                NaN
# 1                Constituency - Environmental      020 7388 6688
# 2     Constituency - Research and independent       +33142811997
# 3                        Constituency - Youth      +441313132488
# 4                        Constituency - Youth  00 45 22 95 40 47
# ...                                       ...                ...
# 2850             Constituency - Environmental        15262994909
# 2851  Constituency - Research and independent   (41-22) 917-8342
# 2852          Constituency - Women and Gender    (1-630)928-1400
# 2853  Constituency - Research and independent  +44 0344 225 1826
# 2854  Constituency - Research and independent                NaN
#
#                     Fax                                 Email  \
# 0                   NaN         emil.wroblewski@fundacja13.pl
# 1                   NaN  alethea.warrington@wearepossible.org
# 2                   NaN          diane@2degrees-investing.org
# 3                   NaN                     contact@2050.scot
# 4                   NaN                       kontakt@dgsb.dk
# ...                 ...                                   ...
# 2850                NaN                       13944696@qq.com
# 2851                NaN                      enzoi@zoinet.org
# 2852    (1-630)928-1559                   zontaintl@zonta.org
# 2853  (44-20) 7586-5743                matthew.lowton@zsl.org
# 2854                NaN                          info@zhaw.ch
#
#                         Coordinator
# 0               Mr. Emil Wroblewski
# 1            Ms. Alethea Warrington
# 2              Mr. Thibaut Ghirardi
# 3               Ms. Sophie Eastwood
# 4     Ms. Esther Michelsen Kjeldahl
# ...                             ...
# 2850                            NaN
# 2851             Mr. Viktor Novikov
# 2852                    M. Radavich
# 2853       Mr. Matthew James Lowton
# 2854              Mr. Martin Jaekel
#
# [2855 rows x 8 columns]

# %%
NGO_unfccc.shape
# Out:
# (2855, 8)

# %%
IGO_unfccc = pd.read_csv("updated_IGOs_UNFCCC.csv")
IGO_unfccc
# Out:
#                                          Official Name            City  \
# 0                          Adaptation Fund Board (AFB)   Washington DC
# 1    African Centre of Meteorological Application f...          Niamey
# 2                African Development Bank Group (AfDB)           Tunis
# 3        African Regional Centre for Technology (ARCT)           Dakar
# 4                       African Union Commission (AUC)     Addis Ababa
# ..                                                 ...             ...
# 136  The Regional Organization for the Conservation...    Jeddah 21583
# 137  Union Economique et Monétaire Ouest Africaine ...  Ouagadougou 01
# 138                  Union for the Mediterranean (UfM)       Barcelona
# 139                      University for Peace (UPEACE)    Ciudad Colón
# 140  West African Science service centre on Climate...           Accra
#
#                       Country              Phone                Fax  \
# 0    United States of America    +1 202 458 7347    +1 202 522 3240
# 1                       Niger   (227-20) 72-3627   (227-20) 72-3627
# 2                     Tunisia    (216) 7110-3900    (216) 7133-5929
# 3                     Senegal       (221)23-7712       (221)23-7713
# 4                    Ethiopia  (251-115) 51-7700  (251-115) 51-7844
# ..                        ...                ...                ...
# 136              Saudi Arabia   (966-2) 657-3224   (966-2) 652-1901
# 137              Burkina Faso    (226) 5031-8873    (226) 5031-8872
# 138                     Spain       +34935214100                NaN
# 139                Costa Rica    (506) 2205-9000                NaN
# 140                     Ghana      +233501529000                NaN
#
#                           Email                      Coordinator
# 0    afbsec@adaptation-fund.org       Mr. Mikko Antti Ollikainen
# 1             dgacmad@acmad.org                   Ms. Safia Alfa
# 2         ifdd@francophonie.org                Mr. Arona Soumare
# 3        arct@sonatel.senet.net                 Mr. Ousmane Kane
# 4      nyambeh@africa-union.org         Mr. Harsen Nyambe Nyambe
# ..                          ...                              ...
# 136             info@persga.org             Mr. Ziad Abu Gararah
# 137        commission@uemoa.int  Mme Zourata Lompo Née Ouédraogo
# 138     info@ufmsecretariat.org          Ms. Cristina Moral Urra
# 139          pcarazo@upeace.org      Sra. Maria Pia Carazo Ortiz
# 140      ouedraogo.f@wascal.org             Mr. Moumini Savadogo
#
# [141 rows x 7 columns]

# %%
IGO_unfccc.shape
# Out:
# (141, 7)

# %%
def populate_country_and_coordinator(cop, unfccc, const):
    org_cop = list(cop["name"])
    org_unfccc = list(unfccc["Official Name"])
    for i in range(len(org_cop)):
        org = org_cop[i]
        for j in range(len(org_unfccc)):
            organization = org_unfccc[j]
            if org in organization:
                cop["country"].iloc[i] = unfccc["Country"].iloc[j]
                cop["city"].iloc[i] = unfccc["City"].iloc[j]
                cop["coordinator"].iloc[i] = unfccc["Coordinator"].iloc[j]
                if const:
                    cop["constituency"].iloc[i] = unfccc["Constituency"].iloc[j]
                break

# %%
populate_country_and_coordinator(NGO, NGO_unfccc, True)
# Out:
# /Users/stefan/py_38_env/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
NGO.head(30)
# Out:
#                                                  name  \
# 0                                  2050 Climate Group
# 1                             2° investing initiative
# 2                 350 the Climate Movement in Denmark
# 3                                             350.org
# 4                               A Rocha International
# 5               A Sud Ecology and Cooperation - Onlus
# 6                                    A Well-Fed World
# 7   Abdullah Bin Hamad Al-Attiyah International Fo...
# 8                                  Abertay University
# 9                                Abibimman Foundation
# 10                 Academy of Science of South Africa
# 11         ACT Alliance - Action by Churches Together
# 12  Action des Chrétiens Activistes des Droits de ...
# 13  Action Group on Erosion, Technology and Concen...
# 14  Action pour la taxation des transactions pour ...
# 15  Action pour le Respect et la Protection de l’E...
# 16             Action Solidarité Tiers-Monde a.s.b.l.
# 17             ActionAid International - South Africa
# 18                                   Adelphi Research
# 19            Advocates for International Development
# 20             Africa Centre for Citizens Orientation
# 21  Africa Youths International Development Founda...
# 22  African Centre for Climate Actions and Rural D...
# 23             African Climate Change Research Centre
# 24                               African Forest Forum
# 25  African Network of Young Leaders for Peace and...
# 26         African Smart Cities Innovation Foundation
# 27                                   African Wildlife
# 28                              Agriconsulting S.p.A.
# 29                                       Agricord vzw
#
#                        entity_type  \
# 0   Non-governmental organizations
# 1   Non-governmental organizations
# 2   Non-governmental organizations
# 3   Non-governmental organizations
# 4   Non-governmental organizations
# 5   Non-governmental organizations
# 6   Non-governmental organizations
# 7   Non-governmental organizations
# 8   Non-governmental organizations
# 9   Non-governmental organizations
# 10  Non-governmental organizations
# 11  Non-governmental organizations
# 12  Non-governmental organizations
# 13  Non-governmental organizations
# 14  Non-governmental organizations
# 15  Non-governmental organizations
# 16  Non-governmental organizations
# 17  Non-governmental organizations
# 18  Non-governmental organizations
# 19  Non-governmental organizations
# 20  Non-governmental organizations
# 21  Non-governmental organizations
# 22  Non-governmental organizations
# 23  Non-governmental organizations
# 24  Non-governmental organizations
# 25  Non-governmental organizations
# 26  Non-governmental organizations
# 27  Non-governmental organizations
# 28  Non-governmental organizations
# 29  Non-governmental organizations
#
#                                          constituency  \
# 0                                Constituency - Youth
# 1             Constituency - Research and independent
# 2                                Constituency - Youth
# 3                    Constituency - Environmental CJN
# 4                        Constituency - Environmental
# 5                        Constituency - Environmental
# 6                        Constituency - Environmental
# 7             Constituency - Research and independent
# 8             Constituency - Research and independent
# 9                    Constituency - Environmental CAN
# 10            Constituency - Research and independent
# 11                   Constituency - Environmental CAN
# 12                                                NaN
# 13                       Constituency - Environmental
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                   Constituency - Environmental CAN
# 18            Constituency - Research and independent
# 19               Constituency - Business and Industry
# 20                       Constituency - Environmental
# 21                               Constituency - Youth
# 22                       Constituency - Environmental
# 23            Constituency - Research and independent
# 24                       Constituency - Environmental
# 25                       Constituency - Environmental
# 26  Constituency - Local government and Municipal ...
# 27                       Constituency - Environmental
# 28               Constituency - Business and Industry
# 29                             Constituency - Farmers
#
#                          coordinator                 city  \
# 0                Ms. Sophie Eastwood            Edinburgh
# 1               Mr. Thibaut Ghirardi                Paris
# 2      Ms. Esther Michelsen Kjeldahl           Copenhagen
# 3            Ms. Cansin Leylim Ilgaz             Brooklyn
# 4                    Mr. Samuel Chiu               London
# 5                    Ms. Lucie Greyl                 Rome
# 6                  Ms. Dawn Moncrief       Washington, DC
# 7                    Mr. John Kilani                 Doha
# 8                   Ms. Rebecca Wade               Dundee
# 9          Mr. Kenneth Nana Amoateng                 Tena
# 10                Ms. Susan Veldsman             Pretoria
# 11                Mr. Thorsten Göbel               Geneva
# 12                               NaN                  NaN
# 13          Mr. Thomas John Wakeford            Val David
# 14                               NaN                  NaN
# 15                               NaN                  NaN
# 16                               NaN                  NaN
# 17  Ms. Teresa Maria Isabel Anderson         Johannesburg
# 18               Mr. Dennis Taenzler               Berlin
# 19              Ms. Yasmin Batliwala               London
# 20       Mr. Peter Olugbenga Adeleye               Kurudu
# 21             Mr. Tunji John Asaolu                Abuja
# 22         Sr. Prof.Augustine Arukwe  Effurun-Delta State
# 23                     Mr. Nura Jibo                Dutse
# 24                 Mr. Godwin Kowero              Nairobi
# 25        Mr. Ismail Joel Eboa Eyoum              Yaoundé
# 26                Mr. David Olatunji                Utako
# 27                Mr. Charly Facheux              Nairobi
# 28              Mr. Giorgio Andreoli                 Rome
# 29    Ms. Gabriela Quiroga Gilardoni             Brussels
#
#                                               country
# 0   United Kingdom of Great Britain and Northern I...
# 1                                              France
# 2                                             Denmark
# 3                            United States of America
# 4   United Kingdom of Great Britain and Northern I...
# 5                                               Italy
# 6                            United States of America
# 7                                               Qatar
# 8   United Kingdom of Great Britain and Northern I...
# 9                                               Ghana
# 10                                       South Africa
# 11                                        Switzerland
# 12                                                NaN
# 13                                             Canada
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                       South Africa
# 18                                            Germany
# 19  United Kingdom of Great Britain and Northern I...
# 20                                            Nigeria
# 21                                            Nigeria
# 22                                            Nigeria
# 23                                            Nigeria
# 24                                              Kenya
# 25                                           Cameroon
# 26                                            Nigeria
# 27                                              Kenya
# 28                                              Italy
# 29                                            Belgium

# %%
NGO.tail(20)
# Out:
#                                                    name  \
# 1577  Wuppertal Institute for Climate, Environment a...
# 1578                                                WWF
# 1579               Yale Student Environmental Coalition
# 1580                                    Yale University
# 1581                                    York University
# 1582  Young Energy Specialists - Development Coopera...
# 1583                          Young European Leadership
# 1584                       Young Power in Social Action
# 1585    Youth Action Environmental Network Lower Saxony
# 1586                       Youth and Environment Europe
# 1587                                  Youth Climate Lab
# 1588                          Youth Climate Movement NL
# 1589                               Youth Climate Report
# 1590                        Youth for Climate - Germany
# 1591                                      Zerofootprint
# 1592       Zhejiang Agriculture and Forestry University
# 1593                            ZOI Environment Network
# 1594                      Zonta International Committee
# 1595                       Zoological Society of London
# 1596              Zurich University of Applied Sciences
#
#                          entity_type                             constituency  \
# 1577  Non-governmental organizations         Constituency - Environmental CAN
# 1578  Non-governmental organizations         Constituency - Environmental CAN
# 1579  Non-governmental organizations             Constituency - Environmental
# 1580  Non-governmental organizations                      Constituency - ENGO
# 1581  Non-governmental organizations  Constituency - Research and independent
# 1582  Non-governmental organizations                     Constituency - Youth
# 1583  Non-governmental organizations                     Constituency - Youth
# 1584  Non-governmental organizations             Constituency - Environmental
# 1585  Non-governmental organizations                     Constituency - Youth
# 1586  Non-governmental organizations                     Constituency - Youth
# 1587  Non-governmental organizations                     Constituency - Youth
# 1588  Non-governmental organizations                     Constituency - Youth
# 1589  Non-governmental organizations                     Constituency - Youth
# 1590  Non-governmental organizations                     Constituency - Youth
# 1591  Non-governmental organizations             Constituency - Environmental
# 1592  Non-governmental organizations  Constituency - Research and independent
# 1593  Non-governmental organizations  Constituency - Research and independent
# 1594  Non-governmental organizations          Constituency - Women and Gender
# 1595  Non-governmental organizations  Constituency - Research and independent
# 1596  Non-governmental organizations  Constituency - Research and independent
#
#                      coordinator                 city  \
# 1577        Mr. Nicolas Kreibich            Wuppertal
# 1578              Mr. Mark Lutes                Gland
# 1579      Ms. Katie Lynn Schlick            New Haven
# 1580            Mr. Donald Filer            New Haven
# 1581     Mr. Richard Bryce Rudyk             New York
# 1582         Mr. Yanniek Huisman              Utrecht
# 1583        Mr. Tillmann Heidelk             Brussels
# 1584  Mr. Mohammad Arifur Rahman           Chittagong
# 1585   Mr. Matthias Paul Nettlau             Hannover
# 1586         Mr. Nathan Méténier               Prague
# 1587   Ms. Ana Gonzalez Guerrero               Ottawa
# 1588            Ms. Aniek Moonen              Utrecht
# 1589              Mr. Mark Terry              Toronto
# 1590               Ms. Pia Jorks  Mülheim an der Ruhr
# 1591               Mr. Ron Dembo              Toronto
# 1592                Mr. Lei Wang             Hangzhou
# 1593          Mr. Viktor Novikov               Geneva
# 1594                 M. Radavich        Oak Brook, IL
# 1595    Mr. Matthew James Lowton               London
# 1596           Mr. Martin Jaekel           Winterthur
#
#                                                 country
# 1577                                            Germany
# 1578                                        Switzerland
# 1579                           United States of America
# 1580                           United States of America
# 1581                           United States of America
# 1582                                        Netherlands
# 1583                                            Belgium
# 1584                                         Bangladesh
# 1585                                            Germany
# 1586                                            Czechia
# 1587                                             Canada
# 1588                                        Netherlands
# 1589                                             Canada
# 1590                                            Germany
# 1591                                             Canada
# 1592                                              China
# 1593                                        Switzerland
# 1594                           United States of America
# 1595  United Kingdom of Great Britain and Northern I...
# 1596                                        Switzerland

# %%
NGO.country.isnull().sum()
# Out:
# 91

# %%
NGO.shape
# Out:
# (1597, 6)

# %%
# initially 491

# %%
NGO.to_csv("NGOs_COP2021_uncleaned.csv", index = False)

# %%
populate_country_and_coordinator(IGO, IGO_unfccc, False)
# Out:
# /Users/stefan/py_38_env/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
IGO.head()
# Out:
#                                                 name  \
# 0                              Adaptation Fund Board
# 1  African Centre of Meteorological Application f...
# 2                     African Development Bank Group
# 3                           African Union Commission
# 4           African, Caribbean and Pacific of States
#
#                        entity_type  constituency                 coordinator  \
# 0  Intergovernmental organizations           NaN  Mr. Mikko Antti Ollikainen
# 1  Intergovernmental organizations           NaN              Ms. Safia Alfa
# 2  Intergovernmental organizations           NaN           Mr. Arona Soumare
# 3  Intergovernmental organizations           NaN    Mr. Harsen Nyambe Nyambe
# 4  Intergovernmental organizations           NaN         Ms. Cristelle Pratt
#
#             city                   country
# 0  Washington DC  United States of America
# 1         Niamey                     Niger
# 2          Tunis                   Tunisia
# 3    Addis Ababa                  Ethiopia
# 4       Brussels                   Belgium

# %%
IGO.country.isnull().sum()
# Out:
# 3

# %%
IGO.drop(columns=["constituency"], inplace = True, axis = 1)

# %%
IGO.head(20)
# Out:
#                                                  name  \
# 0                               Adaptation Fund Board
# 1   African Centre of Meteorological Application f...
# 2                      African Development Bank Group
# 3                            African Union Commission
# 4            African, Caribbean and Pacific of States
# 5                              Asian Development Bank
# 6                Asian Infrastructure Investment Bank
# 7   Autorité de développement intégré de la région...
# 8                                   CAB International
# 9           Caribbean Community Climate Change Centre
# 10                    Caribbean Community Secretariat
# 11         Center for International Forestry Research
# 12  Centre for Environment & Development for Arab ...
# 13                          CGIAR System Organization
# 14  Comité permanent inter-états de lutte contre l...
# 15           Commission des Forêts d’Afrique Centrale
# 16           Commission for Environmental Cooperation
# 17                            Commonwealth Foundation
# 18                           Commonwealth Secretariat
# 19  Convention on Wetlands of International Import...
#
#                         entity_type                        coordinator  \
# 0   Intergovernmental organizations         Mr. Mikko Antti Ollikainen
# 1   Intergovernmental organizations                     Ms. Safia Alfa
# 2   Intergovernmental organizations                  Mr. Arona Soumare
# 3   Intergovernmental organizations           Mr. Harsen Nyambe Nyambe
# 4   Intergovernmental organizations                Ms. Cristelle Pratt
# 5   Intergovernmental organizations                  Ms. Esmyra Javier
# 6   Intergovernmental organizations                     Mr. Xing Zhang
# 7   Intergovernmental organizations  M. Donseg Salvador Aristide Somda
# 8   Intergovernmental organizations                 Mr. Jonathan Casey
# 9   Intergovernmental organizations              Ms. Ethlyn Valladares
# 10  Intergovernmental organizations            Ms. Patricia Ann Nelson
# 11  Intergovernmental organizations            Mr. Christopher Martius
# 12  Intergovernmental organizations                    Ms. Mayar Sabet
# 13  Intergovernmental organizations                 Mr. André Zandstra
# 14  Intergovernmental organizations             Mr. Philippe Zoungrana
# 15  Intergovernmental organizations                                NaN
# 16  Intergovernmental organizations                Ms. Nathalie Daoust
# 17  Intergovernmental organizations         Ms. Anne Therese Gallagher
# 18  Intergovernmental organizations    Mr. Unnikrishnan Divakaran Nair
# 19  Intergovernmental organizations               Ms. Delphine Bremond
#
#                 city                                            country
# 0      Washington DC                           United States of America
# 1             Niamey                                              Niger
# 2              Tunis                                            Tunisia
# 3        Addis Ababa                                           Ethiopia
# 4           Brussels                                            Belgium
# 5   Mandaluyong City                                        Philippines
# 6            Beijing                                              China
# 7      Ouagadougou 1                                       Burkina Faso
# 8               Oxon  United Kingdom of Great Britain and Northern I...
# 9           Belmopan                                             Belize
# 10        Georgetown                                             Guyana
# 11             Bogor                                          Indonesia
# 12             Cairo                                              Egypt
# 13       Montpellier                                             France
# 14    Ouagadougou 03                                       Burkina Faso
# 15               NaN                                                NaN
# 16          Montreal                                             Canada
# 17            London  United Kingdom of Great Britain and Northern I...
# 18            London  United Kingdom of Great Britain and Northern I...
# 19             Gland                                        Switzerland

# %%
IGO.to_csv("IGOs_COP2021_uncleaned.csv", index = False)

# %%
NGO.constituency.unique()
# Out:
# array(['Constituency - Youth', 'Constituency - Research and independent',
#        'Constituency - Environmental CJN', 'Constituency - Environmental',
#        'Constituency - Environmental CAN', nan,
#        'Constituency - Business and Industry',
#        'Constituency - Local government and Municipal authorities',
#        'Constituency - Farmers', 'Constituency - Women and Gender',
#        'Constituency - ENGO', 'Constituency - Indigenous peoples',
#        'Constituency - Trade Unions'], dtype=object)

# %%
len(NGO.constituency.unique())
# Out:
# 13

# %% [markdown]
# # After Manual Data Cleaning - Calculating Country, City and Constituency Statistics

# %% [markdown]
# ## 1. NGOs

# %%
NGO = pd.read_csv("NGOs_COP2021_complete.csv")

# %%
NGO
# Out:
#                                               name  \
# 0                               2050 Climate Group
# 1                          2° investing initiative
# 2              350 the Climate Movement in Denmark
# 3                                          350.org
# 4                            A Rocha International
# ...                                            ...
# 1592  Zhejiang Agriculture and Forestry University
# 1593                       ZOI Environment Network
# 1594                 Zonta International Committee
# 1595                  Zoological Society of London
# 1596         Zurich University of Applied Sciences
#
#                          entity_type                             constituency  \
# 0     Non-governmental organizations                     Constituency - Youth
# 1     Non-governmental organizations  Constituency - Research and independent
# 2     Non-governmental organizations                     Constituency - Youth
# 3     Non-governmental organizations         Constituency - Environmental CJN
# 4     Non-governmental organizations             Constituency - Environmental
# ...                              ...                                      ...
# 1592  Non-governmental organizations  Constituency - Research and independent
# 1593  Non-governmental organizations  Constituency - Research and independent
# 1594  Non-governmental organizations          Constituency - Women and Gender
# 1595  Non-governmental organizations  Constituency - Research and independent
# 1596  Non-governmental organizations  Constituency - Research and independent
#
#                         coordinator           city  \
# 0               Ms. Sophie Eastwood      Edinburgh
# 1              Mr. Thibaut Ghirardi          Paris
# 2     Ms. Esther Michelsen Kjeldahl     Copenhagen
# 3           Ms. Cansin Leylim Ilgaz       Brooklyn
# 4                   Mr. Samuel Chiu         London
# ...                             ...            ...
# 1592                   Mr. Lei Wang       Hangzhou
# 1593             Mr. Viktor Novikov         Geneva
# 1594                    M. Radavich  Oak Brook, IL
# 1595       Mr. Matthew James Lowton         London
# 1596              Mr. Martin Jaekel     Winterthur
#
#                                                 country remarks
# 0     United Kingdom of Great Britain and Northern I...     NaN
# 1                                                France     NaN
# 2                                               Denmark     NaN
# 3                              United States of America     NaN
# 4     United Kingdom of Great Britain and Northern I...     NaN
# ...                                                 ...     ...
# 1592                                              China     NaN
# 1593                                        Switzerland     NaN
# 1594                           United States of America     NaN
# 1595  United Kingdom of Great Britain and Northern I...     NaN
# 1596                                        Switzerland     NaN
#
# [1597 rows x 7 columns]

# %%
# count = 1597 is on par with the official statistics

# %% [markdown]
# ### 1.1 NGO Country Statistics

# %%
NGO_country_stats = pd.DataFrame(NGO.country.value_counts())
NGO_country_stats.reset_index(level=0, inplace=True)
NGO_country_stats.columns = ["Country", "Count"]

# %%
NGO_country_stats
# Out:
#                                               Country  Count
# 0                            United States of America    362
# 1   United Kingdom of Great Britain and Northern I...    285
# 2                                             Germany     91
# 3                                              France     85
# 4                                              Canada     66
# ..                                                ...    ...
# 84                                      Côte d'Ivoire      1
# 85                                            Tunisia      1
# 86                                              Egypt      1
# 87                                 Dominican Republic      1
# 88                                           Holy See      1
#
# [89 rows x 2 columns]

# %%
NGO_country_stats.to_csv("2021_NGO_country_stats.csv")

# %% [markdown]
# ### 1.2 NGO City Statistics

# %%
NGO_city_stats = pd.DataFrame(NGO.city.value_counts())
NGO_city_stats.reset_index(level=0, inplace=True)
NGO_city_stats.columns = ["City", "Count"]

# %%
NGO_city_stats.head(20)
# Out:
#              City  Count
# 0          London    138
# 1      Washington     59
# 2        Brussels     51
# 3           Paris     49
# 4        New York     38
# 5          Berlin     28
# 6          Geneva     20
# 7           Tokyo     17
# 8       New Delhi     14
# 9          Ottawa     14
# 10  San Francisco     13
# 11          Dhaka     13
# 12      Edinburgh     13
# 13        Beijing     12
# 14      Amsterdam     12
# 15           Bonn     12
# 16          Seoul     11
# 17      Cambridge     11
# 18       Montréal     10
# 19        Nairobi     10

# %%
NGO_city_stats.to_csv("2021_NGO_city_stats.csv", index = False)

# %% [markdown]
# ### 1.3 Data Visualizations (barcharts) for Country and City Statistics (NGO)

# %%
# plt.figure(figsize=(20,10))
# plt.subplot(1, 2, 1)
# plt.gca().invert_yaxis()
# plt.barh(NGO_country_stats.Country[0:19], NGO_country_stats.Count[0:19], color = ["green"])
# plt.title("COP2015 NGO Country Statistics \n(first 20 most common countries)")
# plt.xlabel("Number of Organizations")
# plt.xticks(np.arange(0, 250, 20))

# plt.subplot(1, 2, 2)
# plt.gca().invert_yaxis()
# plt.barh(NGO_city_stats.City[0:19], NGO_city_stats.Count[0:19], color = ["blue"])
# plt.title("COP2015 NGO City Statistics \n(first 20 most common cities)")
# plt.xlabel("Number of Organizations")
# plt.xticks(np.arange(0, 50, 5))
# plt.savefig("COP2015_NGO_country_city_stats.png", facecolor = "white", dpi = 400)

# %% [markdown]
# ### 1.4 NGO Constituency Statistics

# %%
NGO.constituency.unique()
# Out:
# array(['Constituency - Youth', 'Constituency - Research and independent',
#        'Constituency - Environmental CJN', 'Constituency - Environmental',
#        'Constituency - Environmental CAN',
#        'Constituency - Business and Industry',
#        'Constituency - Local government and Municipal authorities',
#        'Constituency - Farmers', 'Constituency - Women and Gender', nan,
#        'Constituency - ENGO', 'Constituency - Indigenous peoples',
#        'Constituency - Trade Unions'], dtype=object)

# %%
NGO["constituency"] = NGO["constituency"].replace(np.nan, "not yet affiliated/no data")

# %%
NGO.constituency.unique()
# Out:
# array(['Constituency - Youth', 'Constituency - Research and independent',
#        'Constituency - Environmental CJN', 'Constituency - Environmental',
#        'Constituency - Environmental CAN',
#        'Constituency - Business and Industry',
#        'Constituency - Local government and Municipal authorities',
#        'Constituency - Farmers', 'Constituency - Women and Gender',
#        'not yet affiliated/no data', 'Constituency - ENGO',
#        'Constituency - Indigenous peoples', 'Constituency - Trade Unions'],
#       dtype=object)

# %%
NGO_constituency_stats = pd.DataFrame(NGO.constituency.value_counts())
NGO_constituency_stats.reset_index(level=0, inplace=True)
NGO_constituency_stats.columns = ["Constituency", "Count"]

# %%
NGO_constituency_stats
# Out:
#                                          Constituency  Count
# 0                        Constituency - Environmental    558
# 1             Constituency - Research and independent    434
# 2                Constituency - Business and Industry    186
# 3                    Constituency - Environmental CAN    118
# 4                                Constituency - Youth     89
# 5                   Constituency - Indigenous peoples     47
# 6   Constituency - Local government and Municipal ...     36
# 7                     Constituency - Women and Gender     32
# 8                          not yet affiliated/no data     28
# 9                                 Constituency - ENGO     24
# 10                             Constituency - Farmers     19
# 11                   Constituency - Environmental CJN     16
# 12                        Constituency - Trade Unions     10

# %% [markdown]
# ### 1.4.1 Piechart

# %%
# plt.figure(figsize=(20,10))
# plt.pie(NGO_constituency_stats.Count,labels=NGO_constituency_stats.Constituency,
#         autopct='%1.1f%%',
#         startangle = 0.06,
#         pctdistance = 0.8)
# plt.title("Piechart of Constituency Distribution for NGOs \n(COP2015, n = 1078)")
# plt.savefig("2015_NGO_constituency_piechart.png", facecolor = "white")

# %% [markdown]
# ### 1.4.2 Barchart

# %%
# plt.figure(figsize = (20, 10))
# sns.barplot(y = new_const,
#            x = NGO_constituency_stats.Count,
#            orient='h',
#            color = "blue")
# plt.xticks(np.arange(0, 350, 25))
# plt.title("Barchart of Constituency Distribution for NGOs \n(COP2019)")
# plt.savefig("NGO_constituency_barchart.png", facecolor = "white")

# %% [markdown]
# ### 1.4.3 Map

# %%
def country_name_to_country_alpha3_(country):
    """
    Returns the ISO3 of the country.
    Args: country (str)
    Output: iso3 (str)
    """
    try:
        iso3 = pycountry.country_name_to_country_alpha3(country)
    except:
        iso3 = ""
    return iso3

NGO_country_stats["ISO3"] = [country_name_to_country_alpha3_(country) for country in list(NGO_country_stats.Country)]

# %%
NGO_country_stats[NGO_country_stats.ISO3==""]
# Out:
#                              Country  Count ISO3
# 21                 Republic of Korea     13
# 56  Bolivia (Plurinational State of)      2
# 88                          Holy See      1

# %% [markdown]
# It seems that 3 countries were not identified by the `country_name_to_alpha3` function. These are:
# * Republic of Korea
# * Bolivia
# * Holy See
#
# We will manually compute the ISO3 for these countries as follows:

# %%
NGO_country_stats.loc[[21, 56, 88], "ISO3"] = ["KOR", "BOL", "VAT"]

# %%
NGO_country_stats.tail(10)
# Out:
#                Country  Count ISO3
# 79            Thailand      1  THA
# 80             Senegal      1  SEN
# 81          Madagascar      1  MDG
# 82            Paraguay      1  PRY
# 83           Indonesia      1  IDN
# 84       Côte d'Ivoire      1  CIV
# 85             Tunisia      1  TUN
# 86               Egypt      1  EGY
# 87  Dominican Republic      1  DOM
# 88            Holy See      1  VAT

# %%
NGO_country_stats.to_csv("2021_NGO_country_stats.csv")

# %%
NGO_city_stats.to_csv("2021_NGO_city_stats.csv")

# %%
# fig = px.choropleth(NGO_country_stats, 
#                     locations="ISO3",
#                     color="Count", 
#                     hover_name="Country", # column to add to hover information
#                     color_continuous_scale="reds",
#                     title = "Color-Coded Map of the Country of Origin of NGOs participating at COP2015",
#                     projection = "natural earth",
#                     range_color = [0, 250])

# fig.write_html("Color-Coded Map of the Country of Origin of NGOs participating at COP2015.html")
# fig.show()

# %% [markdown]
# ## 2. IGOs

# %%
IGO = pd.read_csv("IGOs_COP2021_complete.csv")
IGO
# Out:
#                                                  name  \
# 0                               Adaptation Fund Board
# 1   African Centre of Meteorological Application f...
# 2                      African Development Bank Group
# 3                            African Union Commission
# 4            African, Caribbean and Pacific of States
# ..                                                ...
# 70                  Pacific Islands Forum Secretariat
# 71        Parliamentary Assembly of the Mediterranean
# 72  Regional Community Forestry Training Center fo...
# 73      South Asia Co-operative Environment Programme
# 74                        Union for the Mediterranean
#
#                         entity_type                     coordinator  \
# 0   Intergovernmental organizations      Mr. Mikko Antti Ollikainen
# 1   Intergovernmental organizations                  Ms. Safia Alfa
# 2   Intergovernmental organizations               Mr. Arona Soumare
# 3   Intergovernmental organizations        Mr. Harsen Nyambe Nyambe
# 4   Intergovernmental organizations             Ms. Cristelle Pratt
# ..                              ...                             ...
# 70  Intergovernmental organizations            Mr. Exsley Taloiburi
# 71  Intergovernmental organizations            Mr. Giuseppe Belsito
# 72  Intergovernmental organizations        Mr. Ronnakorn Triraganon
# 73  Intergovernmental organizations  Ms. Jacintha Silverine Tissera
# 74  Intergovernmental organizations         Ms. Cristina Moral Urra
#
#              city                   country
# 0   Washington DC  United States of America
# 1          Niamey                     Niger
# 2           Tunis                   Tunisia
# 3     Addis Ababa                  Ethiopia
# 4        Brussels                   Belgium
# ..            ...                       ...
# 70           Suva                      Fiji
# 71     San Marino                San Marino
# 72        Bangkok                  Thailand
# 73     COLOMBO 05                 Sri Lanka
# 74      Barcelona                     Spain
#
# [75 rows x 5 columns]

# %%
# count = 75, which matches with official count

# %% [markdown]
# ### 2.1 Country Statistics

# %%
IGO_country_stats = pd.DataFrame(IGO.country.value_counts())
IGO_country_stats.reset_index(level=0, inplace=True)
IGO_country_stats.columns = ["Country", "Count"]

# %%
IGO_country_stats.head()
# Out:
#                                              Country  Count
# 0                                             France      9
# 1                                            Finland      6
# 2                                        Switzerland      4
# 3  United Kingdom of Great Britain and Northern I...      4
# 4                                              Kenya      3

# %%
IGO_country_stats.to_csv("2021_IGO_country_stats.csv")

# %% [markdown]
# ### 2.2 City Statistics

# %%
IGO_city_stats = pd.DataFrame(IGO.city.value_counts())
IGO_city_stats.reset_index(level=0, inplace=True)
IGO_city_stats.columns = ["City", "Count"]

# %%
IGO_city_stats.head()
# Out:
#        City  Count
# 0     Paris      6
# 1  Helsinki      4
# 2    London      3
# 3   Nairobi      3
# 4   Beijing      2

# %%
IGO_city_stats.to_csv("2021_IGO_city_stats.csv", index = False)

# %% [markdown]
# ### 2.3 Data Visualizations (barcharts) for Country and City Statistics (IGO)

# %%
# plt.figure(figsize=(20,10))
# plt.subplot(1, 2, 1)
# plt.gca().invert_yaxis()
# plt.barh(IGO_country_stats.Country[0:19], IGO_country_stats.Count[0:19], color = ["red"])
# plt.title("COP2015 IGO Country Statistics \n(first 20 most common countries)")
# plt.xlabel("Number of Organizations")
# plt.xticks(np.arange(0,7,1))

# plt.subplot(1, 2, 2)
# plt.gca().invert_yaxis()
# plt.barh(IGO_city_stats.City[0:19], IGO_city_stats.Count[0:19], color = ["purple"])
# plt.title("COP2015 IGO City Statistics \n(first 20 most common cities)")
# plt.xlabel("Number of Organizations")
# plt.xticks(np.arange(0,5,1))
# plt.savefig("COP2015_IGO_country_city_stats.png", facecolor = "white")

# %% [markdown]
# ### Country Map

# %%
IGO_country_stats["ISO3"] = [country_name_to_country_alpha3_(country) for country in list(IGO_country_stats.Country)]

# %%
IGO_country_stats[IGO_country_stats.ISO3==""]
# Out:
#                                Country  Count ISO3
# 27  Venezuela (Bolivarian Republic of)      1
# 33                   Republic of Korea      1

# %% [markdown]
# It seems that 2 countries were not identified by the `country_name_to_alpha3` function. These are:
#
# * Venezuela
# * Republic of Korea
#
# We will manually compute the ISO3 for these countries as follows:

# %%
IGO_country_stats.loc[[27, 33], "ISO3"] = ["VEN", "KOR"]

# %%
IGO_country_stats.tail()
# Out:
#                         Country  Count ISO3
# 40                         Fiji      1  FJI
# 41                     Cameroon      1  CMR
# 42                        India      1  IND
# 43  United Republic of Tanzania      1  TZA
# 44                        Niger      1  NER

# %%
IGO_country_stats.to_csv("2021_IGO_country_stats.csv")

# %%
IGO_city_stats.to_csv("2021_IGO_city_stats.csv")

# %%
# fig = px.choropleth(IGO_country_stats, 
#                     locations="ISO3",
#                     color="Count", 
#                     hover_name="Country", # column to add to hover information
#                     color_continuous_scale="greens",
#                     title = "Color-Coded Map of the Country of Origin of IGOs participating at COP2015",
#                     projection = "natural earth")

# fig.write_html("Color-Coded Map of the Country of Origin of IGOs participating at COP2015.html")
# fig.show()
